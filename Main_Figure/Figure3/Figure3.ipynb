# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

# %% [markdown]
# ## Figure 3a

# %%
meta_corr = pd.read_csv('metacell_correlation.txt', sep='\t', index_col=0)

# %%
figsize = (16, 5)
plt.figure(figsize=figsize)
g = sns.boxplot(x='celltype', y='correlation with metacell', hue='method', width=0.5, data=meta_corr)
plt.ylim(-0.2, 1)
plt.legend(loc='right', bbox_to_anchor=(1.1,0.2), frameon=False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.setp(g.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# ## Figure 3b

# %%
sim_peak_corr = pd.read_csv('simulate_peak_correlation.txt', sep='\t', index_col=0)
sim_cell_corr = pd.read_csv('simulate_cell_correlation.txt', sep='\t', index_col=0)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='corruption fraction', y='correlation with reference', hue='method', width=0.5, data=sim_peak_corr)
sns.despine(offset=10, trim=True)
plt.legend(loc='right', bbox_to_anchor=(1.2,0.2), frameon=False)
# plt.legend().set_visible(False)
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='corruption fraction', y='correlation with reference', hue='method', width=0.5, data=sim_cell_corr)
plt.ylim(-0, 1)
sns.despine(offset=10, trim=True)
plt.legend(loc='right', bbox_to_anchor=(1.2,0.2), frameon=False)
plt.show()
